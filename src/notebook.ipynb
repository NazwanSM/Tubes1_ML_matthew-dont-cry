# %% [markdown]
# # IF3270 Tubes 1 - Feed Forward Neural Network
# ## Kelompok XX
#
# **Anggota Kelompok:**
# - NIM1 - Nama1
# - NIM2 - Nama2
# - NIM3 - Nama3

# %% [markdown]
# ---
# # 1. Inisialisasi & Import Library
# Bagian ini berisi library yang diizinkan:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

data_path = r"../data/datasetml_2026.csv"
df = pd.read_csv(data_path)

print(f"Dataset loaded from: {data_path}")
print(f"Shape: {df.shape}")
display(df.head())
# Out:
# Dataset loaded from: ../data/datasetml_2026.csv
# Shape: (10000, 12)
#        cgpa  backlogs college_tier country university_ranking_band  \
# 0  7.397371         1       Tier 2  Canada                 100-300
# 1  6.889389         0       Tier 3      UK                    300+
# 2  7.518151         0       Tier 1      UK                 100-300
# 3  8.218424         0       Tier 2      UK                 100-300
# 4  6.812677         1       Tier 2     USA                 100-300
#
#    internship_count  aptitude_score  communication_score specialization  \
# 0                 2       53.574150            64.177062   Data Science
# 1                 1       60.687750            88.346052   Data Science
# 2                 2       64.568750            69.493171  Cybersecurity
# 3                 3       73.461500            78.204854          AI/ML
# 4                 4       86.518121            44.680881   Data Science
#
#      industry  internship_quality_score placement_status
# ...

# %% [markdown]
# ---
# # 2. Preprocessing Dataset
# Bagian ini untuk mengolah dataset `global_student_placement_and_salary.csv`:
# - Handling Missing Values
# - Encoding: LabelEncoding/OneHotEncoding untuk kolom kategorikal
# - Scaling: StandardScaler pada fitur numerik
# - Splitting: Train dan Validation set

# %% [markdown]
# ## 2.1. Load Dataset

# %% [markdown]
# ## 2.2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 2.3. Handling Missing Values

# %% [markdown]
# ## 2.4. Encoding Kolom Kategorikal

# %% [markdown]
# ## 2.5. Feature Scaling

# %% [markdown]
# ## 2.6. Train-Validation Split

# %% [markdown]
# ---
# # 3. Implementasi Modul FFNN
# **Catatan:** Kode utama FFNN ada di folder `src/`. Di sini ditampilkan ringkasan class dan cara penggunaannya.

# %% [markdown]
# ---
# # 4. Skenario Pengujian & Analisis
# Bagian ini adalah inti untuk menjawab poin-poin analisis di spesifikasi.

# %% [markdown]
# ## 4.1. Pengaruh Depth dan Width
# Eksperimen untuk menganalisis pengaruh kedalaman (depth) dan lebar (width) hidden layers.

# %% [markdown]
# ### 4.1.1. Eksperimen Variasi Width

# %% [markdown]
# ### 4.1.2. Eksperimen Variasi Depth

# %% [markdown]
# ### 4.1.3. Analisis Depth dan Width
# **TODO: Isi analisis berdasarkan hasil eksperimen**
#
# Analisis hasil eksperimen:
# 1. Pengaruh Width:
#    - ...
#
# 2. Pengaruh Depth:
#    - ...
#
# 3. Kesimpulan:
#    - ...

# %% [markdown]
# ## 4.2. Pengaruh Fungsi Aktivasi Hidden Layer
# Eksperimen menggunakan arsitektur dasar (3 hidden layers) dengan variasi fungsi aktivasi:
# - Linear
# - ReLU
# - Sigmoid
# - Tanh

# %% [markdown]
# ### 4.2.1. Analisis Fungsi Aktivasi
# **TODO: Isi analisis berdasarkan hasil eksperimen**
#
# Analisis hasil eksperimen:
# 1. Perbandingan akurasi antar fungsi aktivasi:
#    - ...
#
# 2. Analisis distribusi bobot/gradien:
#    - ...
#
# 3. Kesimpulan:
#    - ...

# %% [markdown]
# ## 4.3. Pengaruh Learning Rate
# Eksperimen dengan 3 nilai learning rate:

# %% [markdown]
# ### 4.3.1. Analisis Learning Rate
# **TODO: Isi analisis berdasarkan hasil eksperimen**
#
# Analisis hasil eksperimen:
# 1. Kecepatan konvergensi:
#    - LR = 0.1: ...
#    - LR = 0.01: ...
#    - LR = 0.001: ...
#
# 2. Trade-off learning rate tinggi vs rendah:
#    - ...
#
# 3. Kesimpulan:
#    - ...

# %% [markdown]
# ## 4.4. Pengaruh Regularisasi (L1 vs L2)
# Perbandingan:
# - Tanpa Regularisasi
# - L1 Regularization
# - L2 Regularization
#
# Analisis apakah regularisasi membantu mengurangi overfitting (gap antara training & validation loss).

# %% [markdown]
# ### 4.4.1. Analisis Regularisasi
# **TODO: Isi analisis berdasarkan hasil eksperimen**
#
# Analisis hasil eksperimen:
# 1. Perbandingan gap training vs validation loss:
#    - Tanpa Regularisasi: ...
#    - L1: ...
#    - L2: ...
#
# 2. Efektivitas dalam mengurangi overfitting:
#    - ...
#
# 3. Kesimpulan:
#    - ...

# %% [markdown]
# ---
# # 5. Uji Perbandingan dengan Scikit-Learn (MLPClassifier)
# Perbandingan model FFNN buatan dengan `sklearn.neural_network.MLPClassifier` menggunakan hyperparameter yang identik.

# %% [markdown]
# ## 5.1. Analisis Perbandingan dengan Sklearn
# **TODO: Isi analisis berdasarkan hasil eksperimen**
#
# Analisis hasil perbandingan:
# 1. Perbandingan akurasi:
#    - My FFNN: ...
#    - Sklearn MLPClassifier: ...
#
# 2. Perbedaan hasil (jika ada):
#    - ...
#
# 3. Kemungkinan penyebab perbedaan:
#    - ...
#
# 4. Kesimpulan:
#    - ...

# %% [markdown]
# ---
# # 6. Analisis Bonus (Opsional)
# **Catatan:** Bagian ini opsional dan dikerjakan jika mengimplementasikan fitur bonus.

# %% [markdown]
# ## 6.1. Adam vs SGD Optimizer
# Perbandingan grafik konvergensi antara Adam dan SGD optimizer.

# %% [markdown]
# ## 6.2. RMSNorm
# Perbandingan stabilitas gradien dengan dan tanpa RMSNorm.

# %% [markdown]
# ## 6.3. Weight Initialization (Xavier/He vs Random)
# Perbandingan kecepatan konvergensi dengan inisialisasi Xavier/He vs Random Uniform.

# %% [markdown]
# ## 6.4. Analisis Bonus
# **TODO: Isi analisis berdasarkan hasil eksperimen bonus (jika dikerjakan)**
#
# Analisis hasil eksperimen:
# 1. Adam vs SGD:
#    - ...
#
# 2. RMSNorm:
#    - ...
#
# 3. Weight Initialization:
#    - ...
#
# 4. Kesimpulan:
#    - ...

# %% [markdown]
# ---
# # 7. Kesimpulan
#
# **TODO: Isi kesimpulan dari seluruh eksperimen**
#
# ## Ringkasan Hasil Eksperimen
#
# | Eksperimen | Temuan Utama | Konfigurasi Terbaik |
# |------------|--------------|---------------------|
# | Depth & Width | ... | ... |
# | Fungsi Aktivasi | ... | ... |
# | Learning Rate | ... | ... |
# | Regularisasi | ... | ... |
# | Perbandingan Sklearn | ... | ... |
#
# ## Kesimpulan Akhir
# 1. ...
# 2. ...
# 3. ...
#
# ## Saran Pengembangan
# 1. ...
# 2. ...
